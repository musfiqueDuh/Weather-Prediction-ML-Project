# %% [markdown]
# CSE422 (Artificial Intelligence)
#
# *Project Title:*
# **Weather Prediction(Rainfall)**
#
# ---
# Mushfique Billah - 20101002
# MD Muntasir Mahadi - 20101516
#
# Dataset:https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package

# %%
import numpy as np
import pandas as pd

# %%
rain_data = pd.read_csv('D:/mlProject/dev/weatherAUS.csv')
rain_data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # **Dataset Analysis**

# %%
print(type(rain_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print("Shape of data:",rain_data.shape)
# Out:
# Shape of data: (145460, 23)

# %%
print(rain_data.columns)
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
print(rain_data['RainTomorrow'])
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#          ...
# 145455     No
# 145456     No
# 145457     No
# 145458     No
# 145459    NaN
# Name: RainTomorrow, Length: 145460, dtype: object

# %%
print(type(rain_data['RainTomorrow']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
rain_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
rain_data.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# # **Correlation of all the features**

# %%
rain_corr = rain_data.corr(numeric_only=True)
rain_corr
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736555  0.103938     0.466993  0.072586
# MaxTemp        0.736555  1.000000 -0.074992     0.587932  0.470156
# Rainfall       0.103938 -0.074992  1.000000    -0.064351 -0.227549
# Evaporation    0.466993  0.587932 -0.064351     1.000000  0.365602
# Sunshine       0.072586  0.470156 -0.227549     0.365602  1.000000
# WindGustSpeed  0.177415  0.067615  0.133659     0.203021 -0.034750
# WindSpeed9am   0.175064  0.014450  0.087338     0.193084  0.005499
# WindSpeed3pm   0.175173  0.050300  0.057887     0.129400  0.053834
# Humidity9am   -0.232899 -0.504110  0.224405    -0.504092 -0.490819
# Humidity3pm    0.006089 -0.508855  0.255755    -0.390243 -0.629130
# Pressure9am   -0.450970 -0.332061 -0.168154    -0.270362  0.041970
# Pressure3pm   -0.461292 -0.427167 -0.126534    -0.293581 -0.019719
# Cloud9am       0.078754 -0.289370  0.198528    -0.183793 -0.675323
# ...

# %%
import seaborn as sns
sns.heatmap(rain_corr, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # **Checking Null values**

# %%
rain_data.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
round(rain_data.isna().sum() / len(rain_data), 3)
# Out:
# Date             0.000
# Location         0.000
# MinTemp          0.010
# MaxTemp          0.009
# Rainfall         0.022
# Evaporation      0.432
# Sunshine         0.480
# WindGustDir      0.071
# WindGustSpeed    0.071
# WindDir9am       0.073
# WindDir3pm       0.029
# WindSpeed9am     0.012
# WindSpeed3pm     0.021
# Humidity9am      0.018
# Humidity3pm      0.031
# Pressure9am      0.104
# Pressure3pm      0.103
# Cloud9am         0.384
# Cloud3pm         0.408
# Temp9am          0.012
# Temp3pm          0.025
# RainToday        0.022
# RainTomorrow     0.022
# dtype: float64

# %% [markdown]
# # **Null Values Removal**

# %% [markdown]
# **Dropping columns**

# %%
#dropping columns(unnecessary and huge null value)
rain_data = rain_data.drop(['Evaporation','Sunshine','Date'],axis=1)
rain_data.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0   Albury     13.4     22.9       0.6           W           44.0          W
# 1   Albury      7.4     25.1       0.0         WNW           44.0        NNW
# 2   Albury     12.9     25.7       0.0         WSW           46.0          W
# 3   Albury      9.2     28.0       0.0          NE           24.0         SE
# 4   Albury     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday  \
# ...

# %% [markdown]
# **Dropping Rows**

# %%
#dropping rows
rain_data_subset =  rain_data[rain_data['RainTomorrow'].notnull()]
print('shape before dropping rows',rain_data.shape)
print('shape after dropping rows',rain_data_subset.shape)
# Out:
# shape before dropping rows (145460, 20)
# shape after dropping rows (142193, 20)

# %%
not_null_rainData =  rain_data_subset[rain_data_subset['RainToday'].notnull()]
not_null_rainData.shape
# Out:
# (140787, 20)

# %%
final_data = not_null_rainData
final_data.shape
# Out:
# (140787, 20)

# %% [markdown]
# **Imputing missing values**
# (for continuous features)

# %%
from sklearn.impute import SimpleImputer
cont_feature = ['MinTemp','MaxTemp','Rainfall','WindGustSpeed','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp9am','Temp3pm']
for i in range(len(cont_feature)):
  impute = SimpleImputer(missing_values=np.nan, strategy='mean')
  impute.fit(final_data[[cont_feature[i]]])
  final_data[cont_feature[i]] = impute.transform(final_data[[cont_feature[i]]])
  i = i+1
final_data
# Out:
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\3481928687.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data[cont_feature[i]] = impute.transform(final_data[[cont_feature[i]]])
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\3481928687.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data[cont_feature[i]] = impute.transform(final_data[[cont_feature[i]]])
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\3481928687.py:6: SettingWithCopyWarning:
# ...

# %%
round(final_data.isna().sum() / len(final_data), 3)
# Out:
# Location         0.000
# MinTemp          0.000
# MaxTemp          0.000
# Rainfall         0.000
# WindGustDir      0.065
# WindGustSpeed    0.000
# WindDir9am       0.069
# WindDir3pm       0.026
# WindSpeed9am     0.000
# WindSpeed3pm     0.000
# Humidity9am      0.000
# Humidity3pm      0.000
# Pressure9am      0.000
# Pressure3pm      0.000
# Cloud9am         0.000
# Cloud3pm         0.000
# Temp9am          0.000
# Temp3pm          0.000
# RainToday        0.000
# RainTomorrow     0.000
# dtype: float64

# %% [markdown]
# **Imputing missing values** (for Categorical features)

# %%
from sklearn.impute import SimpleImputer
import numpy as np

Cat_features = ['WindGustDir', 'WindDir9am', 'WindDir3pm']
for feature in Cat_features:
    impute = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
    impute.fit(final_data[[feature]])
    final_data[feature] = impute.transform(final_data[[feature]]).ravel()
final_data
# Out:
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\184815022.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data[feature] = impute.transform(final_data[[feature]]).ravel()
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\184815022.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data[feature] = impute.transform(final_data[[feature]]).ravel()
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\184815022.py:8: SettingWithCopyWarning:
# ...

# %%
round(final_data.isna().sum() / len(final_data), 3)
# Out:
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
non_numeric_columns = final_data_encoded.select_dtypes(exclude=['number']).columns
final_data_numeric = final_data_encoded.drop(columns=non_numeric_columns)
sns.heatmap(final_data_numeric, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # **Feature Engineering**

# %%
print(final_data['RainTomorrow'].unique())
print(final_data['RainToday'].unique())
# Out:
# ['No' 'Yes']
# ['No' 'Yes']

# %%
final_data.loc[:, 'RainTomorrow'] = final_data['RainTomorrow'].map({'Yes': 1, 'No': 0})
final_data.loc[:, 'RainToday'] = final_data['RainToday'].map({'Yes': 1, 'No': 0})
final_data
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# ...         ...      ...       ...            ...           ...           ...
# 145454      3.5     21.8       0.0           31.0          15.0          13.0
# 145455      2.8     23.4       0.0           31.0          13.0          11.0
# 145456      3.6     25.3       0.0           22.0          13.0           9.0
# 145457      5.4     26.9       0.0           37.0           9.0           9.0
# 145458      7.8     27.0       0.0           28.0          13.0           7.0
#
# ...

# %% [markdown]
# # **Label Encoding/Categorical Values**

# %%
from sklearn.preprocessing import LabelEncoder

final_data = final_data.copy()
labelencoder = LabelEncoder()
final_data['Location Label'] = labelencoder.fit_transform(final_data['Location'])

final_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\mlProject\env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 5
#       3 final_data = final_data.copy()
# ...

# %%
final_data['WindGustDir_Label'] = labelencoder.fit_transform(final_data['WindGustDir'])
final_data['WindDir9am_Label'] = labelencoder.fit_transform(final_data['WindDir9am'])
final_data['WindDir3pm_Label'] = labelencoder.fit_transform(final_data['WindDir3pm'])

# %%
final_data = final_data.drop(['Location','WindGustDir','WindDir9am','WindDir3pm'],axis=1)
final_data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0     13.4     22.9       0.6           44.0          20.0          24.0
# 1      7.4     25.1       0.0           44.0           4.0          22.0
# 2     12.9     25.7       0.0           46.0          19.0          26.0
# 3      9.2     28.0       0.0           24.0          11.0           9.0
# 4     17.5     32.3       1.0           41.0           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000   4.49925
# 1         44.0         25.0       1010.6       1007.8  4.431161   4.49925
# 2         38.0         30.0       1007.6       1008.7  4.431161   2.00000
# 3         45.0         16.0       1017.6       1012.8  4.431161   4.49925
# 4         82.0         33.0       1010.8       1006.0  7.000000   8.00000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Location Label  \
# ...

# %% [markdown]
# # **Imbalanced Dataset checking**

# %%
rain_tomorrow = final_data[final_data["RainTomorrow"]==1]

not_rain_tomorrow = final_data[final_data["RainTomorrow"]==0]

print('Shape of rainning tomorrow',rain_tomorrow.shape)
print('Shape of not rainning tomorrow',not_rain_tomorrow.shape)
# Out:
# Shape of rainning tomorrow (31201, 20)
# Shape of not rainning tomorrow (109586, 20)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colors = sns.color_palette("pastel")
count_classes = final_data["RainTomorrow"].value_counts()
count_classes.plot(kind="bar", color=colors, rot=0)
plt.title("Transaction class Distribution")
plt.xticks(range(2), ["No", "Yes"])
plt.xlabel("Will rain tomorrow?")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # **Feature value and Target value**

# %%
columns = final_data.columns.tolist()

columns = [c for c in columns if c not in ["RainTomorrow"]]

target = "RainTomorrow"

state = np.random.RandomState(42)

X = final_data[columns]
Y = final_data[target]
x_outliers = state.uniform(low=0, high=1, size=(X.shape[0], X.shape[1]))

# %% [markdown]
# # **Balancing** (under sampling)

# %%
from imblearn.under_sampling import RandomUnderSampler  
under_sampler = RandomUnderSampler()
X, Y = under_sampler.fit_resample(X, Y)
X.shape, Y.shape
# Out:
# ((62402, 19), (62402,))

# %% [markdown]
# # **Scaling**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
X
# Out:
# array([[ 2.10093781,  2.19293456, -0.33512907, ..., -1.76988428,
#         -0.02101109,  0.91420981],
#        [-0.24052875,  0.42333496, -0.33512907, ..., -1.55444623,
#         -0.91324253, -1.08221556],
#        [-0.74004161, -0.47550928, -0.33512907, ..., -0.90813206,
#         -1.35935826, -0.86039052],
#        ...,
#        [ 0.41508189, -0.13844269,  0.28262836, ..., -1.55444623,
#         -0.69018467, -1.52586565],
#        [ 0.80532632,  0.61995714,  0.80953912, ..., -0.04637984,
#         -1.58241612,  0.69238477],
#        [ 0.94581431,  0.85871264,  2.80816613, ..., -1.76988428,
#         -1.58241612, -1.74769069]])

# %% [markdown]
# # **Train and Test data spliting**

# %%
from sklearn.model_selection import train_test_split
#Split the data into 70% training and 30% testing
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (43681, 19)
# (18721, 19)

# %% [markdown]
# Scaling

# %%
# preprocessing using zero mean and unit variance scaling
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler() 
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
print(x_train)
print(x_test)
# Out:
# [[ 1.33453383  0.88397131 -0.31723915 ... -1.76996289  1.31902882
#   -1.75334064]
#  [-0.65067853 -1.12521783 -0.33531151 ...  1.03265809  1.54226638
#    0.91117309]
#  [-1.24467908 -0.14169867 -0.33531151 ...  1.03265809 -0.69010921
#    1.1332159 ]
#  ...
#  [-0.52562579 -1.4062233   3.35144937 ... -1.55437666 -0.69010921
#   -0.64312659]
#  [ 0.47479619  0.37816146 -0.33531151 ... -0.69203175 -0.46687165
#   -0.64312659]
#  [-0.76009969 -0.85826263 -0.33531151 ...  1.03265809  1.54226638
#    0.91117309]]
# [[ 0.88121762  2.12039539 -0.33531151 ...  1.24824432  1.54226638
#    0.24504466]
#  [ 1.70969207  1.16497678 -0.33531151 ... -1.33879044  0.20284102
#   -0.8651694 ]
#  [ 0.59984894  1.86749047 -0.33531151 ... -0.69203175 -1.58305945
#   -0.42108377]
#  ...
#  [ 0.09963795 -0.8723129   0.35143807 ...  1.24824432 -0.02039654
#    1.57730153]
#  [ 0.16216432  0.35006091 -0.33531151 ...  0.60148563  0.20284102
#    0.68913028]
# ...

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Creating model object
model_lg = LogisticRegression(max_iter=120,random_state=0, n_jobs=20)

# %%
# Training Model
model_lg.fit(x_train, y_train.ravel())
# Out:
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\385681247.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   model_lg.fit(x_train, y_train.ravel())
# LogisticRegression(max_iter=120, n_jobs=20, random_state=0)

# %%
# Making Prediction
pred_lg = model_lg.predict(x_test)
pred_lg
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Calculating Accuracy Score
lg = accuracy_score(y_test, pred_lg)
print(lg)
# Out:
# 0.7797660381389883

# %%
print(classification_report(y_test,pred_lg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78      9280
#            1       0.79      0.76      0.78      9441
#
#     accuracy                           0.78     18721
#    macro avg       0.78      0.78      0.78     18721
# weighted avg       0.78      0.78      0.78     18721

# %%
#confusion Maxtrix
cm1 = confusion_matrix(y_test, pred_lg)
sns.heatmap(cm1/np.sum(cm1), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <Axes: >

# %% [markdown]
# # **Naive Bayes Classifier**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Creating model object
model_nv = GaussianNB()

# %%
# Training Model
model_nv.fit(x_train, y_train.ravel())
# Out:
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\1513468748.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   model_nv.fit(x_train, y_train.ravel())
# GaussianNB()

# %%
# Making Prediction
pred_nv = model_nv.predict(x_test)
pred_nv
# Out:
# array([0, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
# Calculating Accuracy Score
nv = accuracy_score(y_test, pred_nv)
print(nv)
# Out:
# 0.7485711233374286

# %%
print(classification_report(y_test,pred_nv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.76      9280
#            1       0.80      0.67      0.73      9441
#
#     accuracy                           0.75     18721
#    macro avg       0.75      0.75      0.75     18721
# weighted avg       0.76      0.75      0.75     18721

# %%
# confusion Maxtrix
cm1 = confusion_matrix(y_test, pred_nv)
sns.heatmap(cm1/np.sum(cm1), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <Axes: >

# %% [markdown]
# ## **KNN Classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Creating model object
model_kn = KNeighborsClassifier

# %%
# Training Model
model_kn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(leaf_size=20, n_neighbors=9)

# %%
# Making Prediction
pred_kn = model_kn.predict(x_test)
pred_kn
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Calculating Accuracy Score
kn = accuracy_score(y_test, pred_kn)
print(kn)
# Out:
# 0.7771486565888575

# %%
print(classification_report(y_test,pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      9280
#            1       0.79      0.76      0.77      9441
#
#     accuracy                           0.78     18721
#    macro avg       0.78      0.78      0.78     18721
# weighted avg       0.78      0.78      0.78     18721

# %%
# confusion Maxtrix
cm5 = confusion_matrix(y_test, pred_kn)
sns.heatmap(cm5/np.sum(cm5), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <Axes: >

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Creating model object
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Training Model
model_rf.fit(x_train, y_train.ravel())
# Out:
# C:\Users\musfi\AppData\Local\Temp\ipykernel_16304\327064894.py:5: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   model_rf.fit(x_train, y_train.ravel())
# RandomForestClassifier(random_state=42)

# %%
# Making Prediction
pred_rf = model_rf.predict(x_test)

# %%
accuracy_rf = accuracy_score(y_test, pred_rf)
print(accuracy_rf)


print(classification_report(y_test, pred_rf))


cm_rf = confusion_matrix(y_test, pred_rf)
sns.heatmap(cm_rf/np.sum(cm_rf), annot=True, fmt='.2%', cmap='Reds')
# Out:
# 0.7980877089899043
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80      9280
#            1       0.81      0.78      0.80      9441
#
#     accuracy                           0.80     18721
#    macro avg       0.80      0.80      0.80     18721
# weighted avg       0.80      0.80      0.80     18721
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


lg = 0.78  
nv = 0.75  
kn = 0.77  
rf = 0.79  


models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Naive Bayes', 'KNeighbours', 'Random Forest'],
    'Accuracy_score': [lg, nv, kn, rf]
})

sns.barplot(x='Accuracy_score', y='Model', data=models)
plt.title('Comparison of Model Accuracies')
plt.xlabel('Accuracy Score')
plt.ylabel('Model')
plt.show()

sorted_models = models.sort_values(by='Accuracy_score', ascending=False)
print(sorted_models)
# Out:
#                  Model  Accuracy_score
# 3        Random Forest            0.79
# 0  Logistic Regression            0.78
# 2          KNeighbours            0.77
# 1          Naive Bayes            0.75
